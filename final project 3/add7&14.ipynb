# %%
import pandas as pd
data=pd.read_csv('applications data(1).csv')

# %%
data.head()
# Out:
#    record      date        ssn  firstname  lastname        address   zip5  \
# 0       1  20160101  379070012   XRRAMMTR  SMJETJMJ  6861 EUTST PL   2765
# 1       2  20160101  387482503   MAMSTUJR  RTTEMRRR  7280 URASA PL  57169
# 2       3  20160101  200332444  SZMMUJEZS  EUSEZRAE  5581 RSREX LN  56721
# 3       4  20160101  747451317  SJJZSXRSZ  ETJXTXXS  1387 UJZXJ RD  35286
# 4       5  20160101   24065868  SSSXUEJMS  SSUUJXUZ   279 EAASA WY   3173
#
#         dob   homephone  fraud_label
# 0  19070626  1797504115            0
# 1  19340615  4164239415            1
# 2  19070626   216537580            0
# 3  19440430   132144161            0
# 4  19980315  6101082272            0

# %%
data[data['date']>=20161101]
# Out:
#          record      date        ssn  firstname  lastname          address  \
# 833507   833508  20161101  947154720  SUSTJTMXU  UESTMJES     6223 RSRU CT
# 833508   833509  20161101  182974033  REXAXJEUR   STSSESZ     2802 XRXA PL
# 833509   833510  20161101  308611124  RTMMTSZRZ  STZRUXZM    1929 RSRRS PL
# 833510   833511  20161101  341458429  XJEEMMJTJ  USTTRXEZ    5973 RMZTA ST
# 833511   833512  20161101  951712374  MEERZUXXU  SMUMSERX    8319 AUXX AVE
# 833512   833513  20161101    8671749   SZUASTTA  RSTRXJSX    5368 UJMXX RD
# 833513   833514  20161101  345924135  UXXJJZTUZ  RJURSTXJ    4528 XTSRZ WY
# 833514   833515  20161101  265346572  XEXRAEMXE  SJXAERRA    1478 RAEET CT
# 833515   833516  20161101  641899311  RAMJRTAST  UXZXMJRS    3646 SUUAT ST
# 833516   833517  20161101  842577650  MSRRAAZZZ   TAJTXZJ    8451 SJMUJ WY
# 833517   833518  20161101  318530622  RSZXMZRSU   SRMJMMT    9922 XSMXJ ST
# ...

# %%
dob=data['dob']

# %%
feature=data[data['date']<=20161031]
#data.groupby('')

# %%
feature[feature['zip5']==2]
# Out:
#         record      date        ssn  firstname  lastname          address  \
# 2353      2354  20160101  197921954  UMSRAEZUZ   SUUMZUE  4515 EAEUR BLVD
# 49406    49407  20160118  162938687   AXRTASAT  RETZEAUE  3614 SURJM BLVD
# 64298    64299  20160124  999999999  RZTJSJETX  UTAMTSUU    6770 UUJZX CT
# 78505    78506  20160129  878104673  RXZMEZMZJ  RUXAMMAA    2541 RJMST ST
# 82342    82343  20160130   95465330  RSRTZATZT  RXXZEMRR    1172 UAZTE ST
# 89559    89560  20160202  457118640  RRSAZXXEJ  EMJZMXZS    4709 RREA AVE
# 108614  108615  20160209  840560161   SZUASTTA   ZRXUURS    3989 EJJZT DR
# 116877  116878  20160212  139892695  XRSJUMZMA  RARTTJJJ    8558 XXJRU LN
# 130994  130995  20160217  210291964  SRZTMEJAT  ETARMJXE    7347 RTRMS DR
# 138728  138729  20160220  544506773  XZSAMXEZR    XMERRR    9943 XJUMJ DR
# 156006  156007  20160226  644046013  UJUJUZMAZ  EAJJXAJT    6267 REURT DR
# 158461  158462  20160227  815141631  UASURUTSX  RARTTJJJ   7459 XTTMS AVE
# ...

# %%
year=[]
for i in dob:
    year.append(int(str(i)[:4]))
month=[]
for i in dob:
    month.append(int(str(i)[4:6]))
day=[]
for i in dob:
    day.append(int(str(i)[6:8]))

# %%
data['birthyear']=year
data['birthmonth']=month
data['birthday']=day

# %%
data.head()
# Out:
#    record      date        ssn  firstname  lastname        address   zip5  \
# 0       1  20160101  379070012   XRRAMMTR  SMJETJMJ  6861 EUTST PL   2765
# 1       2  20160101  387482503   MAMSTUJR  RTTEMRRR  7280 URASA PL  57169
# 2       3  20160101  200332444  SZMMUJEZS  EUSEZRAE  5581 RSREX LN  56721
# 3       4  20160101  747451317  SJJZSXRSZ  ETJXTXXS  1387 UJZXJ RD  35286
# 4       5  20160101   24065868  SSSXUEJMS  SSUUJXUZ   279 EAASA WY   3173
#
#         dob   homephone  fraud_label  birthyear  birthmonth  birthday
# 0  19070626  1797504115            0       1907           6        26
# 1  19340615  4164239415            1       1934           6        15
# 2  19070626   216537580            0       1907           6        26
# 3  19440430   132144161            0       1944           4        30
# 4  19980315  6101082272            0       1998           3        15

# %%
df=pd.read_csv('final from Wendy.csv')
homephone=pd.read_csv('homephone+dob_str.csv')
#list(df.columns).index('datahomephone1agg')  -- 72
df.insert(73, "datahomephone3agg", homephone['datahomephone3agg'], True)
df.insert(74, "datahomephone7agg", homephone['datahomephone7agg'], True)

# %%
df.shape
# Out:
# (1000000, 265)

# %%
list(df.columns)[75]
# Out:
# 'datassnfirstname0agg'

# %%
list(df.columns).index('datadob_strhomephone3agg')
# Out:
# 227

# %%
df.insert(228, "datadob_strhomephone7agg", df['datadob_strhomephone7agg'], True)
df.insert(229, "datadob_strhomephone14agg", homephone['datadob_strhomephone14agg'], True)
df.shape
# Out:
# (1000000, 267)

# %%
list(df.columns).index('datadob_strhomephone7agg')
# Out:
# 228

# %%
list(df.columns)[255]
# Out:
# 'datadob_strhomephone7agg'

# %%
dfcolumn=list(df.columns)
dfcolumn[255]='delete'
df.columns=dfcolumn

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'record',
#  'date',
#  'ssn',
#  'firstname',
#  'lastname',
#  'address',
#  'zip_5',
#  'dob',
#  'homephone',
#  'fraud_label',
#  'dob_str',
#  'zip5_str',
#  'nameDOB',
#  'fulladdress',
#  'Days_since_per_ssn',
#  'Days_since_per_fulladdress',
#  'Days_since_per_nameDOB',
#  'Days_since_per_homephone',
#  'manipulated',
#  'Days_since_per_ssnfirstname',
#  'Days_since_per_ssnlastname',
#  'Days_since_per_ssnaddress',
#  'Days_since_per_ssnzip5_str',
#  'Days_since_per_ssndob_str',
#  'Days_since_per_ssnhomephone',
#  'Days_since_per_ssnnameDOB',
#  'Days_since_per_ssnfulladdress',
#  'Days_since_per_firstnamelastname',
#  'Days_since_per_firstnameaddress',
#  'Days_since_per_firstnamezip5_str',
#  'Days_since_per_firstnamedob_str',
#  'Days_since_per_firstnamehomephone',
#  'Days_since_per_firstnamenameDOB',
#  'Days_since_per_firstnamefulladdress',
#  'Days_since_per_lastnameaddress',
#  'Days_since_per_lastnamezip5_str',
# ...

# %%
# delete irrelavant variable, duplicate variable, and VZ old version variables
df=df.drop(columns=['Unnamed: 0','manipulated','delete','num_zip','num_phones','mean_fraudrate','no_of_apps','no_of_frauds'])

# %%
# load VZ new data
VZ=pd.read_csv('VZ.csv')

# %%
df = pd.merge(df, VZ, on='record')

# %%
list(df.columns)
# Out:
# ['record',
#  'date',
#  'ssn',
#  'firstname',
#  'lastname',
#  'address',
#  'zip_5',
#  'dob',
#  'homephone',
#  'fraud_label',
#  'dob_str',
#  'zip5_str',
#  'nameDOB',
#  'fulladdress',
#  'Days_since_per_ssn',
#  'Days_since_per_fulladdress',
#  'Days_since_per_nameDOB',
#  'Days_since_per_homephone',
#  'Days_since_per_ssnfirstname',
#  'Days_since_per_ssnlastname',
#  'Days_since_per_ssnaddress',
#  'Days_since_per_ssnzip5_str',
#  'Days_since_per_ssndob_str',
#  'Days_since_per_ssnhomephone',
#  'Days_since_per_ssnnameDOB',
#  'Days_since_per_ssnfulladdress',
#  'Days_since_per_firstnamelastname',
#  'Days_since_per_firstnameaddress',
#  'Days_since_per_firstnamezip5_str',
#  'Days_since_per_firstnamedob_str',
#  'Days_since_per_firstnamehomephone',
#  'Days_since_per_firstnamenameDOB',
#  'Days_since_per_firstnamefulladdress',
#  'Days_since_per_lastnameaddress',
#  'Days_since_per_lastnamezip5_str',
#  'Days_since_per_lastnamedob_str',
# ...

# %%
df.shape
# Out:
# (1000000, 270)

# %%
# %%time
df.to_csv('final dataset.csv',index=False)

# %%
check=df.isna().sum()

# %%
check[check==1]  # only this column 'smoothed_zip3' has na
# Out:
# smoothed_zip3    1
# dtype: int64

# %%
df[df['smoothed_zip3'].isna()].transpose()
# Out:
#                                                        882872
# record                                                 882873
# date                                               2016-11-19
# ssn                                                  59848774
# firstname                                           REXMEMMZS
# lastname                                             STZRUXZM
# address                                         7163 UESJS DR
# zip_5                                                      97
# dob                                                  19400322
# homephone                                          4489399089
# fraud_label                                                 0
# dob_str                                              19400322
# zip5_str                                                   97
# nameDOB                           REXMEMMZS_STZRUXZM_19400322
# fulladdress                                  7163 UESJS DR_97
# ...
